# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

x = range(1,51)
y = np.ones(42)*78
y_f = [73,73,76,76,77,77,78,78]
# x = [1,2,3]
# y = [4,5,6]
plt.plot(x,np.concatenate((y_f, y), axis=0),'r-')

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

x = np.array(range(1,101))*10
y = np.ones(92)*91
y_f = [83,87,88,89,90,91,91,91]
# x = [1,2,3]
# y = [4,5,6]
plt.plot(x,np.concatenate((y_f, y), axis=0),'r-')

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

x = range(9,18)
y = [0.91,0.90,0.91,0.92,0.91,0.91,0.90,0.91,0.92]
y2 = [0.56,0.55,0.55,0.56,0.55,0.55,0.56,0.55,0.55]
fig = plt.figure()
fig.suptitle('Number of hidden layer VS Accuracy', fontsize=14, fontweight='bold')
axes = plt.gca()
axes.set_ylim([0.0,1.0])
axes.set_xlabel('number of hidden units in hidden layer1')
axes.set_ylabel('Accuracy')
axes.set_title('red: training accuracy; blue: testing accuracy')
plt.plot(x,y,'r-')
plt.plot(x,y2,'b-')
